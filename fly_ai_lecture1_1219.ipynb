# %% [markdown]
# <a href="https://colab.research.google.com/github/pepsicoc/fly_ai_challenger/blob/main/fly_ai_lecture1_1219.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# !apt-get update -qq
# !apt-get install fonts-nanum* -qq
import matplotlib.font_manager as fm
import warnings
warnings.filterwarnings(action='ignore')
path = '/usr/share/fonts/truetype/nanum/NanumGothic.ttf' # 나눔 고딕
font_name = fm.FontProperties(fname=path, size=10).get_name() # 기본 폰트 사이즈 : 10
plt.rc('font', family=font_name)
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 24 not upgraded.
# Need to get 10.3 MB of archives.
# After this operation, 34.1 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-nanum all 20200506-1 [10.3 MB]
# Fetched 10.3 MB in 1s (12.4 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-nanum.
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
y = np.arange(0, 10)**3
plt.plot(y)
plt.show()

# %%
x = np.linspace(0, 10, 100)
y = np.sin(x)
z = np.cos(x)
plt.plot(x, y)
plt.plot(x, z)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.rc('font', family='NanumBarunGothic')
x = np.arange(0, 10)
y = x**2
plt.plot(x, y)
plt.title('플롯 그래프')
plt.xlabel('X축')
plt.ylabel('Y축')
plt.show()

# %%
x = np.linspace(0, 10, 100)
y1 = np.sin(x)
y2 = np.sin(x + 0.5)
y3 = np.sin(x + 1)
plt.plot(x, y1, 'r--', label='Sin A')
plt.plot(x, y2, 'b.',label='Sin B')
plt.plot(x, y3, 'g-.', label='Sin C')
plt.title('sin 함수')
plt.xlabel('X축')
plt.ylabel('Y축')
plt.legend(loc='upper right')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
x = np.linspace(0, 10, 30)
y = np.sin(x)
z = np.cos(x)
plt.style.use('ggplot')
plt.figure(figsize=(12, 8))
plt.subplot(2, 2, 1)
plt.plot(x, y, 'r-')
plt.subplot(2, 2, 2)
plt.plot(x, z, 'g--')
plt.subplot(2, 2, 3)
plt.plot(x, z, 'b-.')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
x = np.random.rand(30)
y = np.random.rand(30)
plt.scatter(x,y)
plt.show()

# %%
x = ['A','B','C','D']
y = [5. , 25. , 50. , 20.]
plt.bar(x, y)
plt.title('막대그래프')
plt.show()

# %%
name = ['A','B','C','D']
y = [5. , 25. , 50. , 20.]
z = [8. , 20. , 25. , 6.]
fig, ax = plt.subplots(1, 2)
fig.set_size_inches(12, 5)
ax[0].bar(name, y, color='#33aaff')
ax[1].bar(name, z, color=['r', 'g', 'b', 'k'])
plt.title('막대그래프')
plt.show()

# %%
x = np.random.normal(172, 10, 250)
plt.hist(x)
plt.show()

# %%
x = np.random.normal(172, 10, 250)
plt.hist(x, bins=20, color='#05ae1c')
plt.show()

# %%
x = np.random.normal(10, 3, 100)
y = np.random.normal(13, 3, 100)
z = np.random.normal(8, 5, 100)
plt.boxplot([x, y, z], patch_artist=True, sym='ro')
plt.xticks([1, 2, 3], ['A', 'B', 'C'])
plt.savefig('box.png')
plt.show()

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import matplotlib.image as img
image = img.imread('다운로드.jpg')
plt.imshow(image)
plt.xticks([])
plt.yticks([])
plt.show()

# %%
import pandas as pd

# %%
x = [['Jackson', 68, True, 0.82, 'A'], ['Liam', 74, True, 1.1, 'B'], ['Emma', 52, False, 0.89, 'C'],
 ['James', 78, True, 0.91, 'C'], ['Ava', 54, False, 0.73, 'B'], ['Henry', 69, True, 0.78, 'C']]
df = pd.DataFrame(x, columns=['Name', 'Weight', 'Option', 'Rate', 'Type'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    6 non-null      object
#  1   Weight  6 non-null      int64
#  2   Option  6 non-null      bool
#  3   Rate    6 non-null      float64
#  4   Type    6 non-null      object
# dtypes: bool(1), float64(1), int64(1), object(2)
# memory usage: 326.0+ bytes

# %%
df.loc[2:4]
# Out:
#     Name  Weight  Option  Rate Type
# 2   Emma      52   False  0.89    C
# 3  James      78    True  0.91    C
# 4    Ava      54   False  0.73    B

# %%
df.loc[2:4, ['Name', 'Weight']]
# Out:
#     Name  Weight
# 2   Emma      52
# 3  James      78
# 4    Ava      54

# %%
df.loc[2:4, 'Weight']
# Out:
# 2    52
# 3    78
# 4    54
# Name: Weight, dtype: int64

# %%
# !pip install bs4
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1256 sha256=f5b0243c97d6e6c80d5d51c961149017e721ec96d071e84e53db1cd572cdaa20
#   Stored in directory: /root/.cache/pip/wheels/25/42/45/b773edc52acb16cd2db4cf1a0b47117e2f69bb4eb300ed0e70
# Successfully built bs4
# ...

# %%
import requests
from bs4 import BeautifulSoup

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# fonts-nanum is already the newest version (20200506-1).
# 0 upgraded, 0 newly installed, 0 to remove and 39 not upgraded.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 39 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/truetype/humor-sans: skipping, looped directory detected
# ...

# %%
#!pip install requests
import requests
from bs4 import BeautifulSoup as bs
import matplotlib.pyplot as plt
res = requests.get('https://dhlottery.co.kr/common.do?method=main')
soup = bs(res.content, 'html.parser')
result = soup.select('.ball_645')
data = []
for num in result:
 data.append(int(num.text))

plt.rc('font', family='NanumBarunGothic')
plt.bar(['1번'
,'2번'
,'3번'
,'4번'
,'5번'
,'6번'
,'보너스'], data)
plt.show()

# %%
area_card _item

# %%
res = requests.get('http://www.cine21.com/movie/info/?movie_id=58978')
soup = bs(res.content, 'html.parser')
res = soup.select('.comment')

data = []
for num in res:
  data.append(num.text)

data
# Out:
# ['권력이 영원할 줄 아는 사악한 바보들에게',
#  '검사의 봄에 되돌아보는, 뱀의 욕망이 낳은 탄식과 울분의 밤',
#  '여러모로 아슬아슬하다',
#  '‘어떻게 성공했지?’라는 궁금증과 하나회를 향한 분노가 왔다 갔다',
#  '‘전두광 영화’가 되지 않았다는 점이 놀랍다',
#  '바둑을 오셀로로 뒤집으려는 병법의 하룻밤']

# %%
res = requests.get('https://search.naver.com/search.naver?sm=tab_hty.top&where=nexearch&query=%EC%84%9C%EC%9A%B8+%EB%82%A0%EC%94%A8&oquery=%EC%84%9C%EC%9A%B8%EB%82%A0%EC%94%A8&tqi=ihZmjwqVOsCsskhTZSsssssstfV-070681')
soup = bs(res.content, 'html.parser')
res = soup.select('.degree_point')
time = soup.select('.time')

data = []
for num in res:
  i=int(num.text.strip()[:-1])
  #print(i)
  data.append(i)
time_data = []
for t in time:
  time_data.append(t.text)

x = time_data[0:10]
y = data[0:10]
#y = [data[0][6:10],data[1][]]
plt.plot(x,y)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
elements = soup.select('#digital-forecast > div.cmp-dfs-slider.hr1-fct > div.dfs-tab-body > div.dfs-slider > div.slide-wrap.snow-exists.rain-exists > div:nth-child(1) > div > div.item-wrap > ul.item.vs-item.v-item-first > li:nth-child(3) > span.hid.feel')
for element in elements:
		print(element.text)

# %%
# !pip install newspaper3k
import newspaper as news

# %%
link = 'https://sports.news.naver.com/news?oid=477&aid=0000465014'
res = requests.get(link, headers={'User-Agent':'Mozilla/5.0'})
res.content
'''
article = news.Article(link, language='ko')
article.download()
article.parse()
print(article.text)
'''
# Out:
# "\narticle = news.Article(link, language='ko')\narticle.download()\narticle.parse()\nprint(article.text)\n"

# %%
import os
import requests
from bs4 import BeautifulSoup
url = "https://comic.naver.com/webtoon/detail.nhn?titleId=747961&no=2"
html = requests.get(url).text
soup = BeautifulSoup(html, 'html.parser')
if not(os.path.isdir("./webtoon")):
 os.makedirs(os.path.join("./webtoon"))
i = 1
for tag in soup.select('.wt_viewer img'):
 img_url = tag['src']
 save_img = "./webtoon/" + str(i).zfill(3) + img_url[-4:]
 i += 1
 print(save_img + " : OK")
 headers = {'Referer': img_url}
 img_data = requests.get(img_url, headers=headers).content

 with open(save_img, 'wb') as f:
       f.write(img_data)

# %%
import seaborn as sns
print(sns.__version__)
# Out:
# 0.12.2

# %%
import matplotlib.pyplot as plt
titanic=sns.load_dataset('titanic')
print(titanic.head())
print('\n')
print(titanic.info())
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
# ...

# %%
sns.set_style('darkgrid')
fig = plt.figure(figsize=(15, 5))
ax1=fig.add_subplot(1,2,1)
ax2=fig.add_subplot(1,2,2)
sns.histplot(titanic['age'],ax=ax1)
sns.boxplot(x='survived', y='age',data=titanic, ax=ax2)
plt.show()

# %%
# !pip install folium

# %%
import folium
seoul_map = folium.Map(location=[37.5986,126.8645],tiles="CartoDB positron",zoom_start=15)
seoul_map

# %%
import pandas as pd
df = pd.read_excel('./seoulUniv.xlsx', engine= 'openpyxl')
df.head()
# Out:
#             학교명         위도          경도
# 0  KAIST 서울캠퍼스   37.592573  127.046737
# 1         KC대학교  37.548345  126.854797
# 2  가톨릭대학교(성신교정)  37.585922  127.004328
# 3  가톨릭대학교(성의교정)  37.499623  127.006065
# 4      감리교신학대학교  37.567645  126.961610

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47 entries, 0 to 46
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   학교명     47 non-null     object
#  1   위도      47 non-null     float64
#  2   경도      47 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 1.2+ KB

# %%
seoul_map = folium.Map(location=[37.55,126.98], zoom_start=12)
for name, lat, lng in zip(df.index, df.위도, df.경도):
  folium.Marker([lat, lng], popup=name).add_to(seoul_map)
seoul_map

# %%
quickResultLstCon

# %%
url = "https://www.starbucks.co.kr/store/store_map.do"
html = requests.get(url).text
soup = BeautifulSoup(html, 'html.parser')

res=soup.select('.quickResultLstCon')
for i in res:
  print(i.text)

# %%
req = "https://www.starbucks.co.kr/store/store_map.do"
soup = BeautifulSoup(req, "html.parser")
s_list = time = soup.select('.quickResultLstCon')

star_name = []
star_address=[]
star_lat=[]
star_lng=[]
star_gu = []

for s in s_list:
    star_name.append(s.get("data-name"))
    star_address.append(s.find("p","result_details").text.split("1")[0])
    star_gu.append(s.find("p","result_details").text.split()[1])
    star_lat.append(s.get("data-lat"))
    star_lng.append(s.get("data-long"))

star_name
# Out:
# <ipython-input-152-bcba47cdb8f6>:2: MarkupResemblesLocatorWarning: The input looks more like a URL than markup. You may want to use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   soup = BeautifulSoup(req, "html.parser")
# []

# %%
import json
from pandas import json_normalize
targetSite = 'https://www.starbucks.co.kr/store/getStore.do?r=5XLKAT2F0K'
request = requests.post(targetSite, data={
    'ins_lat'   : 37.5108295,           # 위도
    'ins_lng'   : 127.02928809999999,   # 경도
    'p_sido_cd' : '01',                 # 시,도 분류 코드
    'p_gugun_cd': '',                   # 시,군,구 분류 코드
    'in_biz_cd' : '' ,                  # 알 수 없는 정보(불필요)
    'iend'      : 2000,                 # 불러올 최대 매장 수
    'set_date'  : ''                    # 알 수 없는 정보(불필요)
})

star_json = request.json()
star_df = json_normalize(star_json, 'list')

# %%
star_df = json_normalize(star_json, 'list')
print(type(star_df))
print(len(star_df))
star_df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# 612
#      seq sido_cd sido_nm gugun_cd gugun_nm code_order view_yn store_num  sido  \
# 0      0    None    None     None     None       None    None      None  None
# 1      0    None    None     None     None       None    None      None  None
# 2      0    None    None     None     None       None    None      None  None
# 3      0    None    None     None     None       None    None      None  None
# 4      0    None    None     None     None       None    None      None  None
# ..   ...     ...     ...      ...      ...        ...     ...       ...   ...
# 607    0    None    None     None     None       None    None      None  None
# 608    0    None    None     None     None       None    None      None  None
# 609    0    None    None     None     None       None    None      None  None
# 610    0    None    None     None     None       None    None      None  None
# ...

# %%
star_df_map = star_df[['s_name', 'sido_code', 'sido_name', 'gugun_code', 'gugun_name'
                       , 'doro_address', 'lat', 'lot']]

# astype() 메소드로 위도, 경도의 데이터 타입—>object에서 float.
star_df_map['lat'] = star_df_map['lat'].astype(float)
star_df_map['lot'] = star_df_map['lot'].astype(float)
# Out:
# <ipython-input-157-10028af16f16>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   star_df_map['lat'] = star_df_map['lat'].astype(float)
# <ipython-input-157-10028af16f16>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   star_df_map['lot'] = star_df_map['lot'].astype(float)

# %%
star_map = folium.Map(
    location=[star_df_map['lat'].mean(),star_df_map['lot'].mean()],
    zoom_start=12)
for (index, data) in star_df_map.iterrows():
    string = '{}점 - {}'.format(data['s_name'], data['doro_address'])
    popup = folium.Popup(string, max_width=600)
    folium.Marker(
        location=[data['lat'], data['lot']],
        popup=popup
    ).add_to(star_map)
star_map

# %%
import pandas as pd
df = pd.read_csv('./corona2.csv',  encoding = 'cp949' )
df.head()
# Out:
#    자치구  2-6월 1차접종자  2-6월 2차접종자  7월말(누적) 1차접종자  7월말(누적) 2차접종자  8월말(누적) 1차접종자  \
# 0  종로구       64067       28168          79113          40119         114242
# 1   중구       55134       18966          71425          27964          83716
# 2  용산구       65070       23205          82264          32113         122796
# 3  성동구       85252       29483         107896          38956         162919
# 4  광진구       96935       32176         126826          42969         193076
#
#    8월말(누적) 2차접종자  9월말(누적) 1차접종자  9월말(누적) 2차접종자  10월말(누적) 1차접종자  \
# 0          67930         113892          74683          118945
# 1          48807          99187          63028          104060
# 2          67814         173186         114336          180716
# 3          87625         224883         144948          233290
# 4         102210         273100         169311          285027
#
#    10월말(누적) 2차접종자  10월말(누적) 추가접종
# 0          112459            198
# 1           97949            724
# ...

# %%
df_corona=df[['자치구','10월말(누적) 2차접종자']]
df_corona
# Out:
#     자치구  10월말(누적) 2차접종자
# 0   종로구          112459
# 1    중구           97949
# 2   용산구          170709
# 3   성동구          221269
# 4   광진구          268408
# 5   동대문          262492
# 6   중랑구          300751
# 7   성북구          325879
# 8   강북구          230401
# 9   도봉구          244060
# 10  노원구          385016
# 11  은평구          356542
# 12  서대문          233929
# 13  마포구          277168
# 14  양천구          329271
# 15  강서구          431076
# 16  구로구          329521
# 17  금천구          194939
# 18  영등포          314610
# 19  동작구          298095
# 20  관악구          385016
# 21  서초구          292460
# 22  강남구          373874
# 23  송파구          484692
# 24  강동구          343570

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   자치구             25 non-null     object
#  1   2-6월 1차접종자      25 non-null     int64
#  2   2-6월 2차접종자      25 non-null     int64
#  3   7월말(누적) 1차접종자   25 non-null     int64
#  4   7월말(누적) 2차접종자   25 non-null     int64
#  5   8월말(누적) 1차접종자   25 non-null     int64
#  6   8월말(누적) 2차접종자   25 non-null     int64
#  7   9월말(누적) 1차접종자   25 non-null     int64
#  8   9월말(누적) 2차접종자   25 non-null     int64
#  9   10월말(누적) 1차접종자  25 non-null     int64
#  10  10월말(누적) 2차접종자  25 non-null     int64
#  11  10월말(누적) 추가접종   25 non-null     int64
# dtypes: int64(11), object(1)
# memory usage: 2.5+ KB

# %%
#from folium.plugins import CircleMaker
import folium


m = folium.Map(
    location=[37.51, 127.029],
    zoom_start=15
)

coords = sub_df[['위도', '경도']]


marker_cluster = MarkerCluster().add_to(m)

for lat, long in zip(coords['위도'], coords['경도']):
    folium.Marker([lat, long], icon = folium.Icon(color="green")).add_to(marker_cluster)
m
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-acdf026fed45> in <cell line: 10>()
#       8 )
#       9
# ---> 10 coords = sub_df[['위도', '경도']]
#      11
#      12
#
# NameError: name 'sub_df' is not defined

# %%
import pandas as pd
seoul_df = pd.read_csv('./seoul.csv' )
seoul_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 295 entries, 0 to 294
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   docity     295 non-null    object
#  1   do         295 non-null    object
#  2   city       295 non-null    object
#  3   longitude  295 non-null    float64
#  4   latitude   295 non-null    float64
# dtypes: float64(2), object(3)
# memory usage: 11.6+ KB

# %%
seoul_df.head()
# Out:
#   docity  do city   longitude   latitude
# 0  강원강릉시  강원  강릉시  128.878497  37.749136
# 1  강원고성군  강원  고성군  128.470164  38.377961
# 2  강원동해시  강원  동해시  129.116633  37.521931
# 3  강원삼척시  강원  삼척시  129.167489  37.447086
# 4  강원속초시  강원  속초시  128.594167  38.204275

# %%
seoul_df.drop('docity',axis=1)
# Out:
#      do   city   longitude   latitude
# 0    강원    강릉시  128.878497  37.749136
# 1    강원    고성군  128.470164  38.377961
# 2    강원    동해시  129.116633  37.521931
# 3    강원    삼척시  129.167489  37.447086
# 4    강원    속초시  128.594167  38.204275
# ..   ..    ...         ...        ...
# 290  충청    충주시  127.928144  36.988181
# 291  충청    태안군  126.299975  36.742667
# 292  충청  한누리대로  127.289926  36.485450
# 293  충청    홍성군  126.662908  36.598361
# 294  충청    대전시  127.384862  36.350629
#
# [295 rows x 4 columns]

# %%
seoul = seoul_df[seoul_df['do']=='서울']

# %%
seoul=seoul.drop('docity',axis=1)
seoul
# Out:
#      do  city   longitude   latitude
# 138  서울   강남구  127.049556  37.514575
# 139  서울   강동구  127.125864  37.527367
# 140  서울   강북구  127.027719  37.636956
# 141  서울   강서구  126.851675  37.548156
# 142  서울   관악구  126.953844  37.475386
# 143  서울   광진구  127.084533  37.535739
# 144  서울   구로구  126.889597  37.492650
# 145  서울   금천구  126.904197  37.449108
# 146  서울   노원구  127.058389  37.651461
# 147  서울   도봉구  127.049522  37.665833
# 148  서울  동대문구  127.042142  37.571625
# 149  서울   동작구  126.941575  37.509656
# 150  서울   마포구  126.910531  37.560706
# 151  서울  서대문구  126.938897  37.576367
# 152  서울   서초구  127.034811  37.480786
# 153  서울   성동구  127.039000  37.560611
# 154  서울   성북구  127.020333  37.586383
# 155  서울   송파구  127.107931  37.511756
# 156  서울   양천구  126.868708  37.514231
# 157  서울  영등포구  126.898342  37.523611
# 158  서울   용산구  126.967522  37.536094
# 159  서울   은평구  126.931242  37.599969
# 160  서울   종로구  126.981642  37.570378
# 161  서울    중구  126.999642  37.561003
# ...

# %%
seoul_sorted = seoul.sort_values(by='city')
df_sorted = df_corona.sort_values(by='자치구')

# %%
print(seoul_sorted.info())
print(df_sorted.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25 entries, 138 to 162
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   do         25 non-null     object
#  1   city       25 non-null     object
#  2   longitude  25 non-null     float64
#  3   latitude   25 non-null     float64
# dtypes: float64(2), object(2)
# memory usage: 1.5+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25 entries, 22 to 6
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   자치구             25 non-null     object
#  1   10월말(누적) 2차접종자  25 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 1.1+ KB
# None

# %%
seoul_sorted = seoul_sorted.reset_index(drop=True)
df_sorted=df_sorted.reset_index(drop=True)

# %%
from folium.plugins import MarkerCluster
import folium


m = folium.Map(
    location=[37.51, 127.029],
    zoom_start=12
)

for i in range(len(seoul_sorted)):
  folium.CircleMarker(
      location=[seoul_sorted['latitude'][i],seoul_sorted['longitude'][i]],
      color='tomato',
      radius = df_sorted['10월말(누적) 2차접종자'][i]/10000,
      fill=True,
      fill_color='tomato',
      fill_opacity=0.5,
      popup=f"2차 접종자 수: {df_sorted['10월말(누적) 2차접종자'][i]}"
  ).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...
